# %%
# import necessary lib

import pandas as pd
import numpy as np
from scipy import stats
from sklearn.metrics import mean_squared_error

#graph
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer,ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder,StandardScaler,OneHotEncoder
from sklearn.model_selection import GridSearchCV, cross_val_score

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,VotingRegressor,StackingRegressor
import lightgbm as lgb
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.kernel_ridge import KernelRidge

# %% [markdown]
# LOAD DATASET

# %%
train_df=pd.read_csv('../data/train.csv')
test_df=pd.read_csv('../data/test.csv')

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
train_df.columns #81 diff columns quiet large dataset
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# # NUMERİC DATA ANALYSİS

# %%
pd.set_option('display.max_columns',None)
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
train_df.dtypes[train_df.dtypes!='str'] # numeric features
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %% [markdown]
# # OUTLİERS DETECTİON FOR EACH NUMERİC FEATURE

# %%
#MSSubClass: Identifies the type of dwelling involved in the sale.	
#MSSubClass: Satışa konu olan konut tipini tanımlar
plt.scatter(x='MSSubClass',y='SalePrice', data=train_df)

# %%
#LotFrontage: Linear feet of street connected to property
#Parsel Cephesi: Mülke bağlı caddenin doğrusal uzunluğu (ayak cinsinden).
plt.scatter(x='LotFrontage',y='SalePrice', data=train_df)

# %%
# so around 300 is open outliers
train_df.query('LotFrontage >300')
#id 935 and 1299 ll be droped
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 934    935          20       RL        313.0    27650   Pave   NaN      IR2
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 934          HLS    AllPub    Inside       Mod        NAmes       PosA
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 934        Norm     1Fam     1Story            7            7       1960
# 1298       Norm     1Fam     2Story           10            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 934           2007      Flat  Tar&Grv     Wd Sdng     Wd Sdng        NaN
# 1298          2008       Hip  ClyTile      Stucco      Stucco      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# ...

# %%
#LotArea: Lot size in square feet
#Arsa Alanı: Arsa büyüklüğü (metrekare cinsinden)
plt.scatter(x='LotArea',y='SalePrice', data=train_df)

# %%
# over 55k is outliers
train_df.query('LotArea > 55000')
# 250,314,336,707
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1396  1397          20       RL          NaN    57200   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 249          Low    AllPub   CulDSac       Sev      ClearCr       Norm
# 313          Low    AllPub    Inside       Sev       Timber       Norm
# 335          HLS    AllPub    Corner       Sev       Timber       Norm
# 451          Low    AllPub    Inside       Mod      ClearCr       Norm
# ...

# %%
# z score

pd.Series(stats.zscore(train_df['LotArea'])).sort_values().tail(10)
# Out:
# 384      4.268474
# 457      4.280500
# 769      4.308262
# 1396     4.678682
# 1298     5.348867
# 451      6.037793
# 706     10.486449
# 249     14.881285
# 335     15.448542
# 313     20.518273
# dtype: float64

# %%
#OverallQual: Rates the overall material and finish of the house
#OverallQual: Evin genel malzeme ve işçilik kalitesini değerlendirir.
plt.scatter(x='OverallQual',y='SalePrice', data=train_df)

# %%
train_df.query('OverallQual==10') 
#524
# BURDA SIKINTI kalitesi 10 olup fiyatı çok düşük yada çok yüksek olanlarda
# kalites düşükken fiyatın düşük olması outliers olmaz hatta mnatıklıdır
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 58      59          60       RL         66.0    13682   Pave   NaN      IR2
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# 224    225          20       RL        103.0    13472   Pave   NaN      Reg
# 389    390          60       RL         96.0    12474   Pave   NaN      Reg
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 515    516          20       RL         94.0    12220   Pave   NaN      Reg
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 583    584          75       RM         75.0    13500   Pave   NaN      Reg
# 591    592          60       RL         97.0    13478   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 825    826          20       RL        114.0    14803   Pave   NaN      Reg
# ...

# %%
#OverallCond: Rates the overall condition of the house
# evin genel durumu
plt.scatter(x='OverallCond',y='SalePrice', data=train_df)

# %%
train_df.query('OverallCond == 2')
#379
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 88    89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 250  251          30       RL         55.0     5350   Pave   NaN      IR1
# 378  379          20       RL         88.0    11394   Pave   NaN      Reg
# 398  399          30       RM         60.0     8967   Pave   NaN      Reg
# 676  677          70       RM         60.0     9600   Pave  Grvl      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 88          Lvl    AllPub    Corner       Gtl       IDOTRR      Feedr
# 250         Lvl    AllPub    Inside       Gtl      BrkSide       Norm
# 378         Lvl    AllPub    Corner       Gtl      StoneBr       Norm
# 398         Lvl    AllPub    Corner       Gtl       IDOTRR       Norm
# 676         Lvl    AllPub    Inside       Gtl      OldTown       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.query('OverallCond == 5 & SalePrice>700000') 
# çok fazla 5 vardı 2 kısıt kullandık boğulmamamk için
#1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1182         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1182       Norm     1Fam     2Story           10            5       1996
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1182          1996       Hip  CompShg     Wd Sdng     ImStucc        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1182         0.0        Gd        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1182           Av          GLQ        2096          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
train_df.query('OverallCond == 6 & SalePrice>700000') 
#692
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691  692          60       RL        104.0    21535   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 691         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 691       Norm     1Fam     2Story           10            6       1994
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 691          1995     Gable  WdShngl     HdBoard     HdBoard    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 691      1170.0        Ex        TA      PConc       Ex       TA           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 691          GLQ        1455          Unf           0        989         2444
#
# ...

# %%
#build year
plt.scatter(x='YearBuilt',y='SalePrice', data=train_df)

# %%
train_df.query('YearBuilt<1900 & SalePrice>200000') 
#186,305,584,748
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 185  186          75       RM         90.0    22950   Pave   NaN      IR2
# 304  305          75       RM         87.0    18386   Pave   NaN      Reg
# 583  584          75       RM         75.0    13500   Pave   NaN      Reg
# 747  748          70       RM         65.0    11700   Pave  Pave      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 185         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 304         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 583         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 747         Lvl    AllPub    Corner       Gtl      OldTown       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 185       Norm     1Fam     2.5Fin           10            9       1892
# 304       Norm     1Fam     2.5Fin            7            9       1880
# ...

# %%
#YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#YearRemodAdd: Tadilat tarihi (tadilat veya ekleme yapılmadıysa inşaat tarihiyle aynıdır)
plt.scatter(x='YearRemodAdd',y='SalePrice', data=train_df)

# %%
train_df.query('1960<YearRemodAdd<1970 & SalePrice>320000') 
#314
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 313  314          20       RL        150.0   215245   Pave   NaN      IR3
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 313         Low    AllPub    Inside       Sev       Timber       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 313       Norm     1Fam     1Story            7            5       1965
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 313          1965       Hip  CompShg     BrkFace     BrkFace        NaN
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 313         0.0        TA        TA     CBlock       Gd       TA           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 313          ALQ        1236          Rec         820         80         2136
#
# ...

# %%
#MasVnrType: Masonry veneer type
# duvar kaplama türü
plt.scatter(x='MasVnrArea',y='SalePrice', data=train_df)

# %%
train_df.query('MasVnrArea>1500')
#298
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 297  298          60       FV         66.0     7399   Pave  Pave      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 297         Lvl    AllPub    Inside       Gtl      Somerst       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 297       Norm     1Fam     2Story            7            5       1997
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 297          1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 297      1600.0        Gd        TA      PConc       Gd       TA           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 297          BLQ         649          Unf           0        326          975
#
# ...

# %%
train_df.query('400>MasVnrArea>=0 & SalePrice>620000')
#1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1182         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1182       Norm     1Fam     2Story           10            5       1996
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1182          1996       Hip  CompShg     Wd Sdng     ImStucc        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1182         0.0        Gd        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1182           Av          GLQ        2096          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
#BsmtFinType1: Rating of basement finished area
#BsmtFinType1: Bodrum katın bitmiş alanının değerlendirilmesi

plt.scatter(x='BsmtFinSF1',y='SalePrice', data=train_df)

# %%
train_df.query('5000<BsmtFinSF1')
#1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1298       Norm     1Fam     2Story           10            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1298          2008       Hip  ClyTile      Stucco      Stucco      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1298       796.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1298           Gd          GLQ        5644          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
#smtFinType2: Rating of basement finished area (if multiple types)
# birden çok tür varsa
plt.scatter(x='BsmtFinSF2',y='SalePrice', data=train_df)

# %%
train_df.query('400<BsmtFinSF2 & SalePrice>500000')
#441
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 440  441          20       RL        105.0    15431   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 440         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 440       Norm     1Fam     1Story           10            5       2008
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 440          2008       Hip  CompShg     VinylSd     VinylSd      Stone
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 440       200.0        Ex        TA      PConc       Ex       TA           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 440          GLQ        1767          ALQ         539        788         3094
#
# ...

# %%
#BsmtUnfSF: Unfinished square feet of basement area
plt.scatter(x='BsmtUnfSF',y='SalePrice', data=train_df)

# %%
plt.scatter(x='TotalBsmtSF',y='SalePrice', data=train_df)

# %%
train_df.query('5550<TotalBsmtSF ')
#1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1298       Norm     1Fam     2Story           10            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1298          2008       Hip  ClyTile      Stucco      Stucco      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1298       796.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1298           Gd          GLQ        5644          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
plt.scatter(x='1stFlrSF',y='SalePrice', data=train_df)

# %%
plt.scatter(x='2ndFlrSF',y='SalePrice', data=train_df)

# %%
#LowQualFinSF: Low quality finished square feet (all floors)
#LowQualFinSF: Düşük kaliteli bitmiş metrekare (tüm katlar)
plt.scatter(x='LowQualFinSF',y='SalePrice', data=train_df)

# %%
train_df.query('550<LowQualFinSF ')
#186
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 185  186          75       RM         90.0    22950   Pave   NaN      IR2
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 185         Lvl    AllPub    Inside       Gtl      OldTown     Artery
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 185       Norm     1Fam     2.5Fin           10            9       1892
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 185          1993     Gable  WdShngl     Wd Sdng     Wd Sdng        NaN
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 185         0.0        Gd        Gd     BrkTil       TA       TA           Mn
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 185          Unf           0          Unf           0       1107         1107
#
# ...

# %%
plt.scatter(x='GrLivArea',y='SalePrice', data=train_df)

# %%
train_df.query('4000<GrLivArea')
#524 1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 523          Bnk    AllPub    Inside       Gtl      Edwards       PosN
# 691          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1182         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 523        PosN     1Fam     2Story           10            5       2007
# 691        Norm     1Fam     2Story           10            6       1994
# ...

# %%
plt.scatter(x='BsmtFullBath',y='SalePrice', data=train_df)

# %%
train_df.query('2.6<BsmtFullBath')
#739
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 738  739          90       RL         60.0    10800   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 738         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 738       Norm   Duplex     1Story            5            5       1987
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 738          1988     Gable  CompShg     Plywood     Plywood        NaN
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 738         0.0        TA        TA     CBlock       Gd       Gd           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 738          GLQ        1200          Unf           0          0         1200
#
# ...

# %%
plt.scatter(x='BsmtHalfBath',y='SalePrice', data=train_df)

# %%
train_df.query('BsmtHalfBath==2')
#598 955
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 597  598         120       RL         53.0     3922   Pave   NaN      Reg
# 954  955          90       RL         35.0     9400   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 597         Lvl    AllPub    Inside       Gtl      Blmngtn       Norm
# 954         Lvl    AllPub   CulDSac       Gtl      Edwards       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 597       Norm   TwnhsE     1Story            7            5       2006
# 954       Norm   Duplex     SFoyer            6            5       1975
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 597          2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 954          1975      Flat  Tar&Grv     WdShing     Plywood    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
plt.scatter(x='HalfBath', y='SalePrice', data=train_df)

# %%
plt.scatter(x='BedroomAbvGr', y='SalePrice', data=train_df)

# %%
train_df.query('BedroomAbvGr == 8')
#636
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 635  636         190       RH         60.0    10896   Pave  Pave      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 635         Bnk    AllPub    Inside       Gtl        SWISU      Feedr
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 635       Norm   2fmCon     2.5Fin            6            7       1914
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 635          1995       Hip  CompShg     VinylSd     VinylSd        NaN
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 635         0.0        Fa        TA     CBlock       TA       Fa           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 635          LwQ         256          Unf           0       1184         1440
#
# ...

# %%
plt.scatter(x='KitchenAbvGr', y='SalePrice', data=train_df)

# %%
train_df.query('KitchenAbvGr == 3')
#49, 810
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 48    49         190       RM         33.0     4456   Pave   NaN      Reg
# 809  810          75       RM         90.0     8100   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 48          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 809         Lvl    AllPub    Corner       Gtl      OldTown       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 48        Norm   2fmCon     2Story            4            5       1920
# 809       Norm     1Fam     2.5Unf            5            5       1898
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 48           2008     Gable  CompShg     MetalSd     MetalSd        NaN
# 809          1965       Hip  CompShg     AsbShng     AsbShng        NaN
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
plt.scatter(x='TotRmsAbvGrd', y='SalePrice', data=train_df)

# %%
train_df.query('TotRmsAbvGrd == 14')
#636
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 635  636         190       RH         60.0    10896   Pave  Pave      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 635         Bnk    AllPub    Inside       Gtl        SWISU      Feedr
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 635       Norm   2fmCon     2.5Fin            6            7       1914
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 635          1995       Hip  CompShg     VinylSd     VinylSd        NaN
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 635         0.0        Fa        TA     CBlock       TA       Fa           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 635          LwQ         256          Unf           0       1184         1440
#
# ...

# %%
plt.scatter(x='GarageYrBlt', y='SalePrice', data=train_df)

# %%
plt.scatter(x='GarageCars', y='SalePrice', data=train_df)

# %%
plt.scatter(x='GarageArea', y='SalePrice', data=train_df)

# %%
train_df.query('GarageArea > 1200')
#1062, 1191
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 581    582          20       RL         98.0    12704   Pave   NaN      Reg
# 825    826          20       RL        114.0    14803   Pave   NaN      Reg
# 1061  1062          30  C (all)        120.0    18000   Grvl   NaN      Reg
# 1190  1191         190       RL          NaN    32463   Pave   NaN      Reg
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 581          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 825          Lvl    AllPub    Inside       Gtl      NridgHt       PosN
# 1061         Low    AllPub    Inside       Gtl       IDOTRR       Norm
# 1190         Low    AllPub    Inside       Mod      Mitchel       Norm
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
plt.scatter(x='WoodDeckSF', y='SalePrice', data=train_df)

# %%
plt.scatter(x='OpenPorchSF', y='SalePrice', data=train_df)

# %%
train_df.query('OpenPorchSF > 500')
#496
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 583    584          75       RM         75.0    13500   Pave   NaN      Reg
# 1328  1329          50       RM         60.0    10440   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 495          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 583          Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 1328         Lvl    AllPub    Corner       Gtl      OldTown       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 495        Norm     1Fam     1Story            4            5       1920
# 583        PosA     1Fam     2.5Unf           10            9       1893
# 1328       Norm     1Fam     1.5Fin            6            7       1920
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# ...

# %%
plt.scatter(x='EnclosedPorch', y='SalePrice', data=train_df)

# %%
train_df.query('EnclosedPorch > 500')
#198
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197  198          75       RL        174.0    25419   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 197         Lvl    AllPub    Corner       Gtl        NAmes     Artery
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 197       Norm     1Fam     2Story            8            4       1918
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 197          1990     Gable  CompShg      Stucco      Stucco        NaN
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 197         0.0        Gd        Gd      PConc       TA       TA           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 197          GLQ        1036          LwQ         184        140         1360
#
# ...

# %%
plt.scatter(x='3SsnPorch', y='SalePrice', data=train_df)

# %%
plt.scatter(x='ScreenPorch', y='SalePrice', data=train_df)

# %%
plt.scatter(x='PoolArea', y='SalePrice', data=train_df)

# %%
values = [598, 955, 935, 1299, 250, 314, 336, 707, 379, 
          1183, 692, 186, 441, 186, 524, 739, 598, 955, 
          636, 1062, 1191, 496, 198, 1338]

# %%
train_df=train_df[train_df.Id.isin(values)==False]

# %%
train_df[train_df.Id.isin(values)==False]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# nan valeus hadling

# %%
pd.DataFrame(train_df.isnull().sum().sort_values(ascending=False).head(20))
# Out:
#                  0
# PoolQC        1435
# MiscFeature   1388
# Alley         1350
# Fence         1162
# MasVnrType     861
# FireplaceQu    684
# LotFrontage    255
# GarageQual      76
# GarageFinish    76
# GarageType      76
# GarageYrBlt     76
# GarageCond      76
# BsmtFinType2    38
# BsmtExposure    38
# BsmtCond        37
# BsmtQual        37
# BsmtFinType1    37
# MasVnrArea       8
# Electrical       1
# Condition2       0

# %%
train_df['MiscFeature'].unique()
# Out:
# <ArrowStringArray>
# [nan, 'Shed', 'Gar2', 'Othr', 'TenC']
# Length: 5, dtype: str

# %%
train_df['Alley'].unique()
# ara yol tipi
"""Alley: Type of alley access to property

       Grvl	Gravel
       Pave	Paved
       NA 	No alley access"""
# Out:
# 'Alley: Type of alley access to property\n\n       Grvl\tGravel\n       Pave\tPaved\n       NA \tNo alley access'

# %%
train_df['Alley'] = train_df['Alley'].fillna('No')
test_df['Alley'] = test_df['Alley'].fillna('No')

# %%
sns.catplot(data=train_df,x='Alley',y='SalePrice',kind='box')

# %%
train_df.query('Alley=="No"').count()
# Out:
# Id               1350
# MSSubClass       1350
# MSZoning         1350
# LotFrontage      1100
# LotArea          1350
#                  ...
# MoSold           1350
# YrSold           1350
# SaleType         1350
# SaleCondition    1350
# SalePrice        1350
# Length: 81, dtype: int64

# %%
train_df['Fence'].unique()
# çit kalitesi
"""Fence: Fence quality
		
       GdPrv	Good Privacy
       MnPrv	Minimum Privacy
       GdWo	Good Wood
       MnWw	Minimum Wood/Wire
       NA	No Fence
"""
# Out:
# 'Fence: Fence quality\n\n       GdPrv\tGood Privacy\n       MnPrv\tMinimum Privacy\n       GdWo\tGood Wood\n       MnWw\tMinimum Wood/Wire\n       NA\tNo Fence\n'

# %%
train_df['Fence']=train_df['Fence'].fillna('No')
test_df['Fence']=test_df['Fence'].fillna('No')

# %%
sns.catplot(data=train_df,x='Fence',y='SalePrice',kind='box')

# %%
train_df['MasVnrType'].unique()
# Out:
# <ArrowStringArray>
# ['BrkFace', nan, 'Stone', 'BrkCmn']
# Length: 4, dtype: str

# %%
train_df['MasVnrType']
# Out:
# 0       BrkFace
# 1           NaN
# 2       BrkFace
# 3           NaN
# 4       BrkFace
#          ...
# 1455        NaN
# 1456      Stone
# 1457        NaN
# 1458        NaN
# 1459        NaN
# Name: MasVnrType, Length: 1439, dtype: str

# %%
train_df['MasVnrType']=train_df['MasVnrType'].fillna('No')
test_df['MasVnrType']=test_df['MasVnrType'].fillna('No')

# %%
sns.catplot(data=train_df,x='MasVnrType',y='SalePrice',kind='box',color='red')

# %%
train_df['MasVnrArea']=train_df['MasVnrArea'].fillna(0)
test_df['MasVnrArea']=test_df['MasVnrArea'].fillna(0)

# %%
train_df['FireplaceQu'].unique()
# Out:
# <ArrowStringArray>
# [nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po']
# Length: 6, dtype: str

# %%
train_df['FireplaceQu']=train_df['FireplaceQu'].fillna('No')
test_df['FireplaceQu']=test_df['FireplaceQu'].fillna('No')

# %%
sns.catplot(data=train_df,x='FireplaceQu',y='SalePrice',kind='box',color='red')

# %%
sns.catplot(data=train_df,x='Fireplaces',y='SalePrice',kind='box',color='red')

# %%
train_df['LotFrontage']=train_df['LotFrontage'].fillna(0)
test_df['LotFrontage']=test_df['LotFrontage'].fillna(0)

# %%
train_df['GarageYrBlt'].corr(train_df['YearBuilt']) # garj ve bina yılları aynı neredeyse
# Out:
# np.float64(0.8289827595060573)

# %%
train_df['GarageCond'].unique()
# Out:
# <ArrowStringArray>
# ['TA', 'Fa', nan, 'Gd', 'Po', 'Ex']
# Length: 6, dtype: str

# %%
train_df['GarageCond']=train_df['GarageCond'].fillna(0)
test_df['GarageCond']=test_df['GarageCond'].fillna(0)

# %%
sns.catplot(data=train_df,x='GarageCond',y='SalePrice',kind='box',color="#48ff0099")

# %%
train_df['GarageType']=train_df['GarageType'].fillna(0)
test_df['GarageType']=test_df['GarageType'].fillna(0)

# %%
sns.catplot(data=train_df,x='GarageType',y='SalePrice',kind='box')

# %%
train_df['GarageFinish']=train_df['GarageFinish'].fillna(0)
test_df['GarageFinish']=test_df['GarageFinish'].fillna(0)

# %%
train_df['GarageQual']=train_df['GarageQual'].fillna(0)
test_df['GarageQual']=test_df['GarageQual'].fillna(0)

# %%
train_df['BsmtFinType2'].unique()
# Out:
# <ArrowStringArray>
# ['Unf', 'BLQ', nan, 'ALQ', 'Rec', 'LwQ', 'GLQ']
# Length: 7, dtype: str

# %%
train_df['BsmtFinType2']=train_df['BsmtFinType2'].fillna('Unf')
test_df['BsmtFinType2']=test_df['BsmtFinType2'].fillna('Unf')

# %%
train_df['BsmtExposure'].unique()
# Out:
# <ArrowStringArray>
# ['No', 'Gd', 'Mn', 'Av', nan]
# Length: 5, dtype: str

# %%
train_df['BsmtExposure']=train_df['BsmtExposure'].fillna('No')
test_df['BsmtExposure']=test_df['BsmtExposure'].fillna('No')

# %%
train_df['BsmtQual'].unique()
# Out:
# <ArrowStringArray>
# ['Gd', 'TA', 'Ex', nan, 'Fa']
# Length: 5, dtype: str

# %%
train_df['BsmtQual']=train_df['BsmtQual'].fillna('No')
test_df['BsmtQual']=test_df['BsmtQual'].fillna('No')

# %%
train_df['BsmtCond'].unique()
# Out:
# <ArrowStringArray>
# ['TA', 'Gd', nan, 'Fa', 'Po']
# Length: 5, dtype: str

# %%
train_df['BsmtCond']=train_df['BsmtCond'].fillna('No')
test_df['BsmtCond']=test_df['BsmtCond'].fillna('No')

# %%
train_df['BsmtFinType1'].unique()
# Out:
# <ArrowStringArray>
# ['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', nan, 'LwQ']
# Length: 7, dtype: str

# %%
train_df['BsmtFinType1']=train_df['BsmtFinType1'].fillna('No')
test_df['BsmtFinType1']=test_df['BsmtFinType1'].fillna('No')

# %%
train_df['BsmtFinType1'].unique()
# Out:
# <ArrowStringArray>
# ['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', 'No', 'LwQ']
# Length: 7, dtype: str

# %%
#nanları unf yapmam lzmdı
train_df['BsmtFinType1']=train_df['BsmtFinType1'].str.replace('No','Unf')
test_df['BsmtFinType1']=test_df['BsmtFinType1'].str.replace('No','Unf')

# %%
train_df['BsmtFinType1'].unique()
# Out:
# <ArrowStringArray>
# ['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', 'LwQ']
# Length: 6, dtype: str

# %%
train_df['MasVnrArea'].describe()
# Out:
# count    1439.000000
# mean      101.444753
# std       177.273783
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       162.500000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
train_df['MasVnrArea']=train_df['MasVnrArea'].fillna(0)
test_df['MasVnrArea']=test_df['MasVnrArea'].fillna(0)

# %%
train_df['Electrical'].unique()
# Out:
# <ArrowStringArray>
# ['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan]
# Length: 6, dtype: str

# %%
train_df['Electrical']=train_df['Electrical'].fillna('SBrkr')
test_df['Electrical']=test_df['Electrical'].fillna('SBrkr')

# %%
train_df.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1435
# MiscFeature      1388
# GarageYrBlt        76
# MSSubClass          0
# LotArea             0
#                  ...
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 81, dtype: int64

# %% [markdown]
# PoolQC	1435
# MiscFeature	1388
# Alley	1350
# Fence	1162
# MasVnrType	861
# FireplaceQu	684
# LotFrontage	255
# GarageQual	76
# GarageFinish	76
# GarageType	76
# GarageYrBlt	76 #ztn bina yıllı ile aynı modellde kullanmicam gereksiz
# GarageCond	76
# BsmtFinType2	38
# BsmtExposure	38
# BsmtCond	37
# BsmtQual	37
# BsmtFinType1	37
# MasVnrArea	8
# Electrical	1
# Condition2	0

# %%
sns.catplot(data=train_df,x='GarageYrBlt',y='SalePrice',kind='box',color='red') # neredeyse hiç bir etkisi yokl

# %%
train_df = train_df.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'GarageYrBlt', 'GarageCond', 'BsmtFinType2'])
test_df = test_df.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'GarageYrBlt', 'GarageCond', 'BsmtFinType2'])

# %% [markdown]
# # FEATURE ENGINEERING

# %%
train_df['houseage'] = train_df['YrSold'] - train_df['YearBuilt']
test_df['houseage'] = test_df['YrSold'] - test_df['YearBuilt']

# %%
train_df['houseremodelage'] = train_df['YrSold'] - train_df['YearRemodAdd']
test_df['houseremodelage'] = test_df['YrSold'] - test_df['YearRemodAdd']

# %%
train_df['totalsf'] = train_df['1stFlrSF'] + train_df['2ndFlrSF'] + train_df['BsmtFinSF1'] + train_df['BsmtFinSF2']
test_df['totalsf'] = test_df['1stFlrSF'] + test_df['2ndFlrSF'] + test_df['BsmtFinSF1'] + test_df['BsmtFinSF2']

# %%
train_df['totalarea'] = train_df['GrLivArea'] + train_df['TotalBsmtSF']
test_df['totalarea'] = test_df['GrLivArea'] + test_df['TotalBsmtSF']

# %%
train_df['totalbaths'] = train_df['BsmtFullBath'] + train_df['FullBath'] + 0.5 * (train_df['BsmtHalfBath'] + train_df['HalfBath']) 
test_df['totalbaths'] = test_df['BsmtFullBath'] + test_df['FullBath'] + 0.5 * (test_df['BsmtHalfBath'] + test_df['HalfBath'])

# %%
train_df['totalporchsf'] = train_df['OpenPorchSF'] + train_df['3SsnPorch'] + train_df['EnclosedPorch'] + train_df['ScreenPorch'] + train_df['WoodDeckSF']
test_df['totalporchsf'] = test_df['OpenPorchSF'] + test_df['3SsnPorch'] + test_df['EnclosedPorch'] + test_df['ScreenPorch'] + test_df['WoodDeckSF']

# %%
train_df = train_df.drop(columns=['Id','YrSold', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'BsmtFinSF1', 'BsmtFinSF2', 'GrLivArea', 'TotalBsmtSF','BsmtFullBath', 'FullBath', 'BsmtHalfBath', 'HalfBath', 'OpenPorchSF', '3SsnPorch', 'EnclosedPorch', 'ScreenPorch','WoodDeckSF'])
test_df = test_df.drop(columns=['YrSold', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'BsmtFinSF1', 'BsmtFinSF2', 'GrLivArea', 'TotalBsmtSF','BsmtFullBath', 'FullBath', 'BsmtHalfBath', 'HalfBath', 'OpenPorchSF', '3SsnPorch', 'EnclosedPorch', 'ScreenPorch','WoodDeckSF'])

# %%
corr_matrix=train_df.corr(numeric_only=True)
plt.figure(figsize=(20,16))
sns.heatmap(data=corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
#drop GarageArea or GarageCars
train_df = train_df.drop(columns=['GarageArea'])
test_df = test_df.drop(columns=['GarageArea'])

# %%
sns.histplot(
    train_df,
    x=train_df['SalePrice'],
)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
train_df['SalePrice'] = np.log1p(train_df['SalePrice'])

# %%
sns.histplot(
    train_df,
    x=train_df['SalePrice']
)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
train_df.dtypes[train_df.dtypes.isin(['object','string'])]
# Out:
# MSZoning         str
# Street           str
# LotShape         str
# LandContour      str
# Utilities        str
# LotConfig        str
# LandSlope        str
# Neighborhood     str
# Condition1       str
# Condition2       str
# BldgType         str
# HouseStyle       str
# RoofStyle        str
# RoofMatl         str
# Exterior1st      str
# Exterior2nd      str
# MasVnrType       str
# ExterQual        str
# ExterCond        str
# Foundation       str
# BsmtQual         str
# BsmtCond         str
# BsmtExposure     str
# BsmtFinType1     str
# Heating          str
# HeatingQC        str
# CentralAir       str
# Electrical       str
# KitchenQual      str
# Functional       str
# FireplaceQu      str
# PavedDrive       str
# SaleType         str
# SaleCondition    str
# dtype: object

# %%
train_df.select_dtypes(include=['number']).dtypes
# Out:
# MSSubClass           int64
# LotFrontage        float64
# LotArea              int64
# OverallQual          int64
# OverallCond          int64
# MasVnrArea         float64
# BsmtUnfSF            int64
# LowQualFinSF         int64
# BedroomAbvGr         int64
# KitchenAbvGr         int64
# TotRmsAbvGrd         int64
# Fireplaces           int64
# GarageCars           int64
# PoolArea             int64
# MiscVal              int64
# MoSold               int64
# SalePrice          float64
# houseage             int64
# houseremodelage      int64
# totalsf              int64
# totalarea            int64
# totalbaths         float64
# totalporchsf         int64
# dtype: object

# %%
train_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
train_df.shape
# Out:
# (1439, 60)

# %%
ode_cols = ['LotShape', 'LandContour','Utilities','LandSlope',  'BsmtQual',  'BsmtFinType1',  'CentralAir',  'Functional', \
           'FireplaceQu', 'GarageFinish', 'GarageQual', 'PavedDrive', 'ExterCond', 'KitchenQual', 'BsmtExposure', 'HeatingQC','ExterQual', 'BsmtCond']

# %%
ohe_cols = ['Street', 'LotConfig','Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st', 'Exterior2nd', \
           'MasVnrType','Foundation',  'Electrical',  'SaleType', 'MSZoning', 'SaleCondition', 'Heating', 'GarageType', 'RoofMatl']

# %%
# 'number' anahtar kelimesi int64, float64, int32 vb. hepsini kapsar
num_cols = train_df.select_dtypes(include=['number']).columns
num_cols = num_cols.drop('SalePrice')

# %%
print(len(ode_cols)+len(ohe_cols)+len(num_cols) +1)
# Out:
# 60

# %%
id="find_problem"
for col in train_df.columns:
    types = train_df[col].map(type).unique()
    if len(types) > 1:
        print(col, types)

problem_cols = ['GarageType', 'GarageFinish', 'GarageQual']

for col in problem_cols:
    train_df[col] = train_df[col].replace(0, "No")
    train_df[col] = train_df[col].astype(str)
for col in problem_cols:
    test_df[col] = test_df[col].replace(0, "No")
    test_df[col] = test_df[col].astype(str)
    
problem_cols = ['GarageType', 'GarageFinish', 'GarageQual']

for col in problem_cols:
    train_df[col] = train_df[col].replace(0, "No")
    train_df[col] = train_df[col].astype(str)
# Out:
# GarageType [<class 'str'> <class 'int'>]
# GarageFinish [<class 'str'> <class 'int'>]
# GarageQual [<class 'str'> <class 'int'>]

# %% [markdown]
# # Pipeline kısmı

# %%
num_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

#nanlara mean bizde yok ama emniyet kemeri hesabı sonra standartlaştır

# %%
ode_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('ode', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])
#handle_unknown='use_encoded_value': Eğer test setinde, 
# eğitim (train) setinde hiç görmediği yeni bir kategori 
# ile karşılaşırsa hata vermek yerine senin belirlediğin 
# bir değeri atar.
#unknown_value=-1: Bilinmeyen 
# o yeni kategoriye -1 değerini verir. Bu, modelin "bu veri 
# hakkında bilgim yok" demesini sağlar ve kodun çökmesini önler.

# nanlara en çok tekrar edeni at ve ordinalencoder uygula

# %%
ohe_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

#2. Adım: ('ohe', OneHotEncoder(...))
#handle_unknown='ignore': Bu çok kritiktir. 
# Test verisinde, eğitim verisinde (train) hiç bulunmayan 
# bir kategori (örneğin eğitimde hiç olmayan yeni bir mahalle 
# ismi) gelirse hata fırlatmak yerine, o satır için tüm OHE 
# sütunlarına 0 yazar.

#sparse_output=False: Normalde OHE, bellekten tasarruf etmek 
# için veriyi "seyrek matris" (sparse matrix) olarak saklar. 
# Bunu False yaparak veriyi doğrudan okunabilir bir NumPy 
# dizisine (veya yoğun matrise) çevirirsin. Bu, 
# veriyi birleştirirken veya incelemek istediğinde işini 
# kolaylaştırır.

# %%
col_trans = ColumnTransformer(transformers=[
    ('num_p', num_pipeline, num_cols),
    ('ode_p', ode_pipeline, ode_cols),
    ('ohe_p', ohe_pipeline, ohe_cols),
    ],
    remainder='passthrough', 
    n_jobs=-1)

# %%
pipeline = Pipeline(steps=[
    ('preprocessing', col_trans)
])

# %%
X = train_df.drop(columns=['SalePrice'])
y = train_df['SalePrice']

# %%
X_preprocessed = pipeline.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=25)

# %% [markdown]
# # Models part

# %%
lr= LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=lr.predict(X_test)

# %%
a=mean_squared_error(y_test,y_pred_lr)

# %%
lr.score(X_test,y_test)
# Out:
# 0.8878474925996478

# %%
np.sqrt(a)
# Out:
# np.float64(0.1331288263658318)

# %%
rfr=RandomForestRegressor(random_state=13)

# %%
param_grid_rfr={
    'max_depth':[5,10,15],
    'n_estimators':[100,250,500],
    'min_samples_split':[3,5,10]
}

# %%
rfr_grid=GridSearchCV(estimator=rfr,param_grid=param_grid_rfr,cv=5,scoring='neg_mean_squared_error',n_jobs=-1)

# %%
rfr_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=13), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15],
#                          'min_samples_split': [3, 5, 10],
#                          'n_estimators': [100, 250, 500]},
#              scoring='neg_mean_squared_error')

# %%
rfr_grid.best_params_
# Out:
# {'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 500}

# %%
np.sqrt(-1*rfr_grid.best_score_)
# Out:
# np.float64(0.1339531434811936)

# %%
xgb=XGBRegressor(random_state=13)
param_grid_xgb={
    'learning_rate':[0.05,0.1,0.2],
    'n_estimators':[300],
    'max_depth':[3],
    'min_child_weight':[1,2,3],
    'gamma':[0,0.1,0.2],
    'subsample':[0.8,0.9,1.0],
    'colsample_bytree':[0.8,0.9,1.0]
}

xgb_grid=GridSearchCV(estimator=xgb,param_grid=param_grid_xgb,cv=3,n_jobs=-1,scoring='neg_mean_squared_error')
xgb_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
# ...

# %%
np.sqrt(-1*xgb_grid.best_score_)
# Out:
# np.float64(0.11788482845739556)

# %%
ridge=Ridge()
param_grid_ridge={
    'alpha':[0.05,0.1,1,3,5,10],
    'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag']
}
ridge_grid=GridSearchCV(estimator=ridge,param_grid=param_grid_ridge,cv=5,n_jobs=-1,scoring='neg_mean_squared_error')
ridge_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [0.05, 0.1, 1, 3, 5, 10],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag']},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1*ridge_grid.best_score_)
# Out:
# np.float64(0.10909691388621942)

# %%
gbr=GradientBoostingRegressor()
param_grid_gbr={
    
    'max_depth':[12,15,20],
    'n_estimators':[200,300,1000],
    'min_samples_leaf':[10,25,50],
    'learning_rate':[0.001,0.01,0.1],
    'max_features':[0.01,0.1,0.7]

}
gbr_grid=GridSearchCV(gbr,param_grid_gbr,cv=5,n_jobs=-1,scoring='neg_mean_squared_error')
gbr_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [12, 15, 20],
#                          'max_features': [0.01, 0.1, 0.7],
#                          'min_samples_leaf': [10, 25, 50],
#                          'n_estimators': [200, 300, 1000]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1*gbr_grid.best_score_)
# Out:
# np.float64(0.1133470169693469)

# %%
lgbm=lgb.LGBMRegressor()
param_grid_lgbm={
    'bosting_type':['gbdt','dart'],
    'num_leaves':[20,30,40],
    'learnig_rate':[0.01,0.05,0.1],
    'n_estimators':[100,200,300]
}
lgbm_grid=GridSearchCV(lgbm,param_grid_lgbm,cv=3,n_jobs=-1,scoring='neg_mean_squared_error')
lgbm_grid.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Unknown parameter: bosting_type
# [LightGBM] [Warning] Unknown parameter: learnig_rate
# [LightGBM] [Warning] Unknown parameter: bosting_type
# [LightGBM] [Warning] Unknown parameter: learnig_rate
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001091 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1994
# [LightGBM] [Info] Number of data points in the train set: 1151, number of used features: 112
# [LightGBM] [Info] Start training from score 12.023259
# GridSearchCV(cv=3, estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'bosting_type': ['gbdt', 'dart'],
#                          'learnig_rate': [0.01, 0.05, 0.1],
#                          'n_estimators': [100, 200, 300],
#                          'num_leaves': [20, 30, 40]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1*lgbm_grid.best_score_)
# Out:
# np.float64(0.12755291061931714)

# %%
# could take good resut but u have to work on the variables a lot
vr=VotingRegressor(estimators=[
    ('gbr',gbr_grid.best_estimator_),
    ('xgb',xgb_grid.best_estimator_),
    ('ridge',ridge_grid.best_estimator_)
],weights=(2,3,1))

vr.fit(X_train,y_train)
# Out:
# VotingRegressor(estimators=[('gbr',
#                              GradientBoostingRegressor(learning_rate=0.01,
#                                                        max_depth=20,
#                                                        max_features=0.1,
#                                                        min_samples_leaf=25,
#                                                        n_estimators=1000)),
#                             ('xgb',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=0.9, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_m...
# ...

# %%
y_pred_vr=vr.predict(X_test)
b=mean_squared_error(y_test,y_pred_vr)
np.sqrt(b)
# Out:
# np.float64(0.11956473149687502)

# %%
catboost=CatBoostRegressor(loss_function='RMSE',verbose=False)
param_gri_cat={
    'iterations':[100,500,1000],
    'depth':[4,6,8,10],
    'learning_rate':[0.001,0.01,0.1,0.5]
}

cat_grid=GridSearchCV(catboost,param_gri_cat,cv=3, scoring='neg_mean_squared_error',n_jobs=-1)
cat_grid.fit(X_train,y_train)
# Out:
# c:\Users\computeer\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 3 fits failed out of a total of 144.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\computeer\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\computeer\AppData\Local\Programs\Python\Python313\Lib\site-packages\catboost\core.py", line 6178, in fit
# ...

# %%
np.sqrt(-1*cat_grid.best_score_)
# Out:
# np.float64(0.1156105243036746)

# %%
estimators = [
    ('gbr', gbr_grid.best_estimator_),
    ('xgb', xgb_grid.best_estimator_),
    ('cat', cat_grid.best_estimator_),
    ('lgb', lgbm_grid.best_estimator_),
    ('rfr', rfr_grid.best_estimator_),
]
stackreg = StackingRegressor(
            estimators = estimators,
            final_estimator = vr
)
stackreg.fit(X_train,y_train)
# Out:
# [LightGBM] [Warning] Unknown parameter: bosting_type
# [LightGBM] [Warning] Unknown parameter: learnig_rate
# [LightGBM] [Warning] Unknown parameter: bosting_type
# [LightGBM] [Warning] Unknown parameter: learnig_rate
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1994
# [LightGBM] [Info] Number of data points in the train set: 1151, number of used features: 112
# [LightGBM] [Info] Start training from score 12.023259
# [LightGBM] [Warning] Unknown parameter: bosting_type
# [LightGBM] [Warning] Unknown parameter: learnig_rate
# [LightGBM] [Warning] Unknown parameter: bosting_type
# [LightGBM] [Warning] Unknown parameter: learnig_rate
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001270 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1896
# ...

# %%
y_pred_stack=stackreg.predict(X_test)
c=mean_squared_error(y_test,y_pred_stack)
# Out:
# [LightGBM] [Warning] Unknown parameter: bosting_type
# [LightGBM] [Warning] Unknown parameter: learnig_rate
# c:\Users\computeer\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
np.sqrt(c)
# Out:
# np.float64(0.11570807533562281)

# %%
df_test_preprocess = pipeline.transform(test_df)
y_stacking = np.exp(stackreg.predict(df_test_preprocess))

df_y_stacking_out = test_df[['Id']]
df_y_stacking_out['SalePrice'] = y_stacking

df_y_stacking_out.to_csv('submission.csv', index=False)
# Out:
# c:\Users\computeer\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: bosting_type
# [LightGBM] [Warning] Unknown parameter: learnig_rate
